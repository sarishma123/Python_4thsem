# %% [markdown]
# <h1>First Look Data with Pandas</h1>
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRWkCG5kkVQwhKLSO8V_FR3YMBRUuflaPRaFiFnMQHI6pjyiKhLjwdKuSU&s=10" width="200" height="200">

# %%
import pandas as pd
import matplotlib as plt

# %%
df=pd.read_csv(r'C:\Users\Dell\Python_4th_Sem\numpyand pandas\pandas_intro_practice_500_rows.csv')

# %%
df.head()
# Out:
#    Employee_ID      Name   Age       City  Department    Salary     Product  \
# 0           35     Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183    Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86      Neha  32.0    Chitwan          IT   96376.0       Mouse
# 3          274    Sabin   21.0     Dharan  Operations   52479.0      Webcam
# 4           37      Maya  55.0  Kathmandu          IT   34862.0    Keyboard
#
#    Quantity  Rating  Joining_Year
# 0         9     3.0          2018
# 1         8     3.1          2019
# 2         3     4.6          2020
# 3         5     4.3          2019
# 4         9     1.1          2023

# %%
df.tail()
# Out:
#      Employee_ID   Name   Age       City Department    Salary     Product  \
# 495          114  Nisha  28.0     Butwal  Marketing   90771.0  Headphones
# 496           97   Riya  35.0     Dharan  Marketing    $43958      Tablet
# 497          226    Raj  34.0  Bhaktapur         HR   87676.0    Keyboard
# 498          215   Riya  33.0  Bhaktapur  Marketing   60537.0  Headphones
# 499           58  Suman  46.0  Kathmandu         HR  134168.0      Tablet
#
#      Quantity  Rating  Joining_Year
# 495         3     2.0          2025
# 496         4     4.7          2020
# 497         8     4.0          2023
# 498         3     1.4          2021
# 499         7     4.6          2018

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Age', 'City', 'Department', 'Salary', 'Product',
#        'Quantity', 'Rating', 'Joining_Year'],
#       dtype='str')

# %%
df["Name"].head()
# Out:
# 0       Sneha
# 1      Aayush
# 2        Neha
# 3      Sabin
# 4        Maya
# Name: Name, dtype: str

# %%
df[["Name", "Age", "City"]].head()
# Out:
#        Name   Age       City
# 0     Sneha  33.0     Butwal
# 1    Aayush  37.0  Bhaktapur
# 2      Neha  32.0    Chitwan
# 3    Sabin   21.0     Dharan
# 4      Maya  55.0  Kathmandu

# %%
df[df["Age"]>30].head()
# Out:
#    Employee_ID    Name   Age       City  Department    Salary     Product  \
# 0           35   Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183  Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86    Neha  32.0    Chitwan          IT   96376.0       Mouse
# 4           37    Maya  55.0  Kathmandu          IT   34862.0    Keyboard
# 5            6     Raj  43.0  Bhaktapur  Operations   34116.0      Laptop
#
#    Quantity  Rating  Joining_Year
# 0         9     3.0          2018
# 1         8     3.1          2019
# 2         3     4.6          2020
# 4         9     1.1          2023
# 5         4     4.1          2019

# %%
df[(df["City"] == "Kathmandu") & (df["Product"] == "Keyboard")]
# Out:
#      Employee_ID    Name   Age       City  Department    Salary   Product  \
# 4             37    Maya  55.0  Kathmandu          IT   34862.0  Keyboard
# 169          417  Ramesh  42.0  Kathmandu  Operations  140336.0  Keyboard
# 192          420   Sabin  23.0  Kathmandu  Operations  147469.0  Keyboard
# 228           36    Maya  37.0  Kathmandu          IT   68719.0  Keyboard
# 300           29    Amit  30.0  Kathmandu   Marketing   35500.0  Keyboard
# 308          371    Sita  45.0  Kathmandu   Marketing   99870.0  Keyboard
# 373          257   Sabin  50.0  Kathmandu  Operations   26238.0  Keyboard
# 439          159   Sabin  53.0  Kathmandu  Operations   69140.0  Keyboard
# 457          412   Kiran  49.0  Kathmandu          IT  131584.0  Keyboard
#
#      Quantity  Rating  Joining_Year
# 4           9     1.1          2023
# 169         8     4.7          2019
# 192         9     4.4          2025
# 228         5     1.6          2025
# 300         2     NaN          2021
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID     0
# Name            0
# Age             6
# City            5
# Department      6
# Salary          6
# Product         0
# Quantity        0
# Rating          6
# Joining_Year    0
# dtype: int64

# %% [markdown]
# Clear a missing number

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df[(df["Age"]>18) & (df["Age"]<60)].head()
# Out:
#    Employee_ID      Name   Age       City  Department    Salary     Product  \
# 0           35     Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183    Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86      Neha  32.0    Chitwan          IT   96376.0       Mouse
# 3          274    Sabin   21.0     Dharan  Operations   52479.0      Webcam
# 4           37      Maya  55.0  Kathmandu          IT   34862.0    Keyboard
#
#    Quantity  Rating  Joining_Year
# 0         9     3.0          2018
# 1         8     3.1          2019
# 2         3     4.6          2020
# 3         5     4.3          2019
# 4         9     1.1          2023

# %%
df["Age"].mean()
# Out:
# np.float64(39.444)

# %%
df["age"]=df["Age"].apply(lambda x: "Adult" if x>=18 else "Child")
print(df.head())
# Out:
#    Employee_ID      Name   Age       City  Department    Salary     Product  \
# 0           35     Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183    Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86      Neha  32.0    Chitwan          IT   96376.0       Mouse
# 3          274    Sabin   21.0     Dharan  Operations   52479.0      Webcam
# 4           37      Maya  55.0  Kathmandu          IT   34862.0    Keyboard
#
#    Quantity  Rating  Joining_Year    age
# 0         9     3.0          2018  Adult
# 1         8     3.1          2019  Adult
# 2         3     4.6          2020  Adult
# 3         5     4.3          2019  Adult
# 4         9     1.1          2023  Adult

# %%
df["age"].value_counts()
# Out:
# age
# Adult    500
# Name: count, dtype: int64

# %%
df["Age"].median()
# Out:
# np.float64(38.0)

# %%
df["Rating"]=df["Rating"].fillna(df["Rating"].mean())
print(df.head())
# Out:
#    Employee_ID      Name   Age       City  Department    Salary     Product  \
# 0           35     Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183    Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86      Neha  32.0    Chitwan          IT   96376.0       Mouse
# 3          274    Sabin   21.0     Dharan  Operations   52479.0      Webcam
# 4           37      Maya  55.0  Kathmandu          IT   34862.0    Keyboard
#
#    Quantity  Rating  Joining_Year    age
# 0         9     3.0          2018  Adult
# 1         8     3.1          2019  Adult
# 2         3     4.6          2020  Adult
# 3         5     4.3          2019  Adult
# 4         9     1.1          2023  Adult

# %%
df=df.dropna(subset=["Product", "City"])
print(df.head())
# Out:
#    Employee_ID      Name   Age       City  Department    Salary     Product  \
# 0           35     Sneha  33.0     Butwal          HR  115111.0  Headphones
# 1          183    Aayush  37.0  Bhaktapur          IT   28396.0    Keyboard
# 2           86      Neha  32.0    Chitwan          IT   96376.0       Mouse
# 3          274    Sabin   21.0     Dharan  Operations   52479.0      Webcam
# 4           37      Maya  55.0  Kathmandu          IT   34862.0    Keyboard
#
#    Quantity  Rating  Joining_Year    age
# 0         9     3.0          2018  Adult
# 1         8     3.1          2019  Adult
# 2         3     4.6          2020  Adult
# 3         5     4.3          2019  Adult
# 4         9     1.1          2023  Adult

# %%
df.isnull().sum()
# Out:
# Employee_ID     0
# Name            0
# Age             0
# City            0
# Department      6
# Salary          6
# Product         0
# Quantity        0
# Rating          0
# Joining_Year    0
# age             0
# dtype: int64

# %% [markdown]
# Deleting dupilcate

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 495, dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Employee_ID    Name   Age        City Department    Salary     Product  \
# 68            83    Neha  23.0     Pokhara         HR       NaN       Mouse
# 80           299  Ramesh  51.0    Lalitpur  Marketing       NaN  Headphones
# 96           422   Rahul  25.0      Dharan        NaN  130022.0      Webcam
# 108          472   Priya  31.0    Lalitpur        NaN  103908.0     Monitor
# 188          268    Amit  30.0     Chitwan        NaN   43198.0  Headphones
# 203          213   Nisha  51.0      Butwal      Sales       NaN  Headphones
# 283          116  Ramesh  20.0  Biratnagar        NaN   41199.0      Webcam
# 343          258  Aayush  26.0   Kathmandu        NaN   52710.0      Webcam
# 372          325   Priya  31.0   Kathmandu  Marketing       NaN      Tablet
# 377          443    Sita  52.0    Lalitpur      Sales       NaN      Tablet
# 392           28   Nisha  38.0   Bhaktapur        NaN  100914.0      Laptop
# ...

# %%
df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 495, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df["City"]=df["City"].str.strip().str.title()
print(df["City"].unique())
# Out:
# <StringArray>
# [    'Butwal',  'Bhaktapur',    'Chitwan',     'Dharan',  'Kathmandu',
#    'Lalitpur',    'Pokhara', 'Biratnagar']
# Length: 8, dtype: str

# %%
df["Salary"]=df["Salary"].str.replace(",","").astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df["Salary"]=df["Salary"].str.replace(",","").astype(float)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:6529, in NDFrame.astype(self, dtype, copy, errors)
#    6525             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6526
#    6527         else:
#    6528             # else, only a single dtype is given
# -> 6529             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6530             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6531             return res.__finalize__(self, method="astype")
#    6532
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\internals\managers.py:627, in BaseBlockManager.astype(self, dtype, errors)
# ...
