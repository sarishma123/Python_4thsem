# %%
import pandas as pd
print(pd.__version__)
# Out:
# 3.0.5

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s + [1000, 2000, 3000, 4000, 5000]
# Out:
# 0    1001
# 1    2002
# 2    3003
# 3    4004
# 4    5005
# dtype: int64

# %%
s2=pd.Series([68, 75, 80, 90, 95], index=['Math', 'Science', 'English', 'History', 'Art'])
s2.loc['Math']
# Out:
# np.int64(68)

# %%
pd.DataFrame({
    'bob': [10, 20, 30, 40, 50],
    'alice': [5, 15, 25, 35, 45]
}, index=['product A', 'product B', 'product C', 'product D', 'product E'])
# Out:
#            bob  alice
# product A   10      5
# product B   20     15
# product C   30     25
# product D   40     35
# product E   50     45

# %%
s.loc['product A', 'bob']
# Out:
# np.int64(10)

# %%
people_dict={
    "weight":pd.Series([68,83,112], index=["Alice","Bob","Charlie"]),
    "birthyear":pd.Series([1984,1990,2000], index=["Alice","Bob","Charlie"], name="year"),
    "childern":pd.Series([1,2,3], index=["Alice","Bob","Charlie"], name="children"),
    "hobby":pd.Series(["reading","swimming","cooking"], index=["Alice","Bob","Charlie"], name="hobby")
}
people=pd.DataFrame(people_dict)
print(people)
# Out:
#          weight  birthyear  childern     hobby
# Alice        68       1984         1   reading
# Bob          83       1990         2  swimming
# Charlie     112       2000         3   cooking

# %%
import pandas as pd
import numpy as np

ds = pd.DataFrame(
    {
        ("public", "birthyear"):
            {("Paris", "alice"): 1985,
             ("Paris", "bob"): 1984,
             ("London", "charles"): 1992},

        ("public", "hobby"):
            {("Paris", "alice"): "Biking",
             ("Paris", "bob"): "Dancing"},

        ("private", "weight"):
            {("Paris", "alice"): 68,
             ("Paris", "bob"): 83,
             ("London", "charles"): 112},

        ("private", "children"):
            {("Paris", "alice"): np.nan,
             ("Paris", "bob"): 3,
             ("London", "charles"): 0}
    }
)

print(ds)
# Out:
#                   public          private
#                birthyear    hobby  weight children
# Paris  alice        1985   Biking      68      NaN
#        bob          1984  Dancing      83      3.0
# London charles      1992      NaN     112      0.0

# %%
# Out:
#   Cell In[20], line 1
#     <h1>First Look at DATA with PANDAS</h1>
#     ^
# SyntaxError: invalid syntax
